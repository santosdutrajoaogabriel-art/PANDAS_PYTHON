# %% [markdown]
# <a href="https://colab.research.google.com/github/santosdutrajoaogabriel-art/Pandas-transforma-o-e-manipula-o-de-dados/blob/main/json_normalize.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
pd.read_json('/content/informacoes.json')
# Out:
#    nome  idade                                          enderecos
# 0  João     28  {'tipo': 'casa', 'rua': 'Rua A', 'numero': 123...
# 1  João     28  {'tipo': 'trabalho', 'rua': 'Rua B', 'numero':...

# %%
import json

# %%
with open('informacoes.json') as f:
 json_main = json.load(f)

# %%
json_main
# Out:
# {'nome': 'João',
#  'idade': 28,
#  'enderecos': [{'tipo': 'casa',
#    'rua': 'Rua A',
#    'numero': 123,
#    'cidade': 'São Paulo'},
#   {'tipo': 'trabalho',
#    'rua': 'Rua B',
#    'numero': 456,
#    'cidade': 'Rio de Janeiro'}]}

# %%
dados_normalizados = pd.json_normalize(json_main)

# %%
dados_normalizados
# Out:
#    nome  idade                                          enderecos
# 0  João     28  [{'tipo': 'casa', 'rua': 'Rua A', 'numero': 12...

# %%
dados_normalizados = pd.json_normalize(json_main, record_path='enderecos', meta = ['nome', 'idade'])

# %%
dados_normalizados
# Out:
#        tipo    rua  numero          cidade  nome idade
# 0      casa  Rua A     123       São Paulo  João    28
# 1  trabalho  Rua B     456  Rio de Janeiro  João    28
